# %%
with open("../data/clean_logs.txt") as f:
    logs = [line.strip() for line in f]

# print(logs[:100])
print(list(set(logs)))
# Out:
# ['Receiving block source path destination', 'BLOCK path block', 'Receiving block source path destination', 'Receiving block source path destination', 'PacketResponder for block terminating', 'PacketResponder for block terminating', 'Received block of size from path', 'Received block of size from path', 'PacketResponder for block terminating', 'Received block of size from path', 'BLOCK blockMap updated ip is added to block size', 'BLOCK blockMap updated ip is added to block size', 'BLOCK blockMap updated ip is added to block size', 'Receiving block source path destination', 'Receiving block source path destination', 'BLOCK path block', 'Received block source path destination of size', 'Receiving block source path destination', 'Receiving block source path destination', 'Receiving block source path destination', 'PacketResponder for block terminating', 'Received block of size from path', 'PacketResponder for block terminating', 'Received block of size from path', 'ip Transmitted block 
# ...

# %%
clean_logs = list(set(logs))
